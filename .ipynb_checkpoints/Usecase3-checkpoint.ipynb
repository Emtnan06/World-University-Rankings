# %%
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install scipy
# !pip3 install openpyxl

# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
import re
#from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
#%matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
shanghai_Rank2022 = pd.read_excel("Data\shanghai Ranking.xlsx")
shanghai_Rank2023 = pd.read_csv("Data\shanghai-ranking_2023.csv")
Times_Higher_Rank = pd.read_excel("Data\Times Higher Education.xlsx")
World_Rank = pd.read_excel("Data\Word Rank University.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_12984\1175436076.py:1: SyntaxWarning: invalid escape sequence '\s'
#   shanghai_Rank2022 = pd.read_excel("Data\shanghai Ranking.xlsx")
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_12984\1175436076.py:2: SyntaxWarning: invalid escape sequence '\s'
#   shanghai_Rank2023 = pd.read_csv("Data\shanghai-ranking_2023.csv")
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_12984\1175436076.py:3: SyntaxWarning: invalid escape sequence '\T'
#   Times_Higher_Rank = pd.read_excel("Data\Times Higher Education.xlsx")
# C:\Users\rahaf\AppData\Local\Temp\ipykernel_12984\1175436076.py:4: SyntaxWarning: invalid escape sequence '\W'
#   World_Rank = pd.read_excel("Data\Word Rank University.xlsx")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
print("The size of dataset shanghai Ranking is \n" , shanghai_Rank2023.shape ,"\nThe size of dataset Times Higher Education is \n" , Times_Higher_Rank.shape ,"\nThe size of dataset World Rank University is \n" , World_Rank.shape )
# Out:
# The size of dataset shanghai Ranking is
#  (1000, 19)
# The size of dataset Times Higher Education is
#  (1591, 20)
# The size of dataset World Rank University is
#  (2000, 9)

# %% [markdown]
# # Shanghai Rank 2022  Academic Ranking

# %%
shanghai_Rank2022.head()
# Out:
#   Ranking                              University Name National/Regional Rank  \
# 0       1                           Harvard University                      1
# 1       2                          Stanford University                      2
# 2       3  Massachusetts Institute of Technology (MIT)                      3
# 3       4                      University of Cambridge                      1
# 4       5           University of California, Berkeley                      4
#
#    Total Score                                               LOGO  \
# 0        100.0  http://www.shanghairanking.com/_uni/logo/032bd...
# 1         76.8  http://www.shanghairanking.com/_uni/logo/13de8...
# 2         70.1  http://www.shanghairanking.com/_uni/logo/79165...
# 3         69.6  http://www.shanghairanking.com/_uni/logo/8d986...
# 4         65.3  http://www.shanghairanking.com/_uni/logo/0ff17...
#
#                                   University Detail
# 0  http://www.shanghairanking.com/institution/har...
# 1  http://www.shanghairanking.com/institution/sta...
# 2  http://www.shanghairanking.com/institution/mas...
# 3  http://www.shanghairanking.com/institution/uni...
# 4  http://www.shanghairanking.com/institution/uni...

# %%
shanghai_Rank2022
# Out:
#       Ranking                                University Name  \
# 0           1                             Harvard University
# 1           2                            Stanford University
# 2           3    Massachusetts Institute of Technology (MIT)
# 3           4                        University of Cambridge
# 4           5             University of California, Berkeley
# ..        ...                                            ...
# 995  901-1000                        University of Wuppertal
# 996  901-1000                Warsaw University of Technology
# 997  901-1000  Western Norway University of Applied Sciences
# 998  901-1000   Wroclaw University of Science and Technology
# 999  901-1000                              Yantai University
#
#     National/Regional Rank  Total Score  \
# 0                        1        100.0
# 1                        2         76.8
# 2                        3         70.1
# 3                        1         69.6
# 4                        4         65.3
# ..                     ...          ...
# 995                  46-47          0.0
# 996                   7-11          0.0
# 997                    6-7          0.0
# 998                   7-11          0.0
# 999                148-163          0.0
#
#                                                   LOGO  \
# 0    http://www.shanghairanking.com/_uni/logo/032bd...
# 1    http://www.shanghairanking.com/_uni/logo/13de8...
# 2    http://www.shanghairanking.com/_uni/logo/79165...
# 3    http://www.shanghairanking.com/_uni/logo/8d986...
# 4    http://www.shanghairanking.com/_uni/logo/0ff17...
# ..                                                 ...
# 995  http://www.shanghairanking.com/_uni/logo/2ab2f...
# 996  http://www.shanghairanking.com/_uni/logo/a347c...
# 997  http://www.shanghairanking.com/_uni/logo-jpg/d...
# 998  http://www.shanghairanking.com/_uni/logo/ed480...
# 999  http://www.shanghairanking.com/_uni/logo/78347...
#
#                                     University Detail
# 0    http://www.shanghairanking.com/institution/har...
# 1    http://www.shanghairanking.com/institution/sta...
# 2    http://www.shanghairanking.com/institution/mas...
# 3    http://www.shanghairanking.com/institution/uni...
# 4    http://www.shanghairanking.com/institution/uni...
# ..                                                 ...
# 995  http://www.shanghairanking.com/institution/uni...
# 996  http://www.shanghairanking.com/institution/war...
# 997  http://www.shanghairanking.com/institution/wes...
# 998  http://www.shanghairanking.com/institution/wro...
# 999  http://www.shanghairanking.com/institution/yan...
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Shanghai Rank 2023  Academic Ranking

# %%
# Some ranks are duplicated because some universities obtained the same rank and the next rank is skipped accordingly

# %%
# Rankings are grouped into ranges after 100 rank, with every 150 ranks forming a separate range. 
# then after 200 rank every 200 ranks forming a separate range.

# %%
shanghai_Rank2023.head()
# Out:
#   Rank                                               Logo  \
# 0    1  https://www.shanghairanking.com/_uni/logo/032b...
# 1    2  https://www.shanghairanking.com/_uni/logo/13de...
# 2    3  https://www.shanghairanking.com/_uni/logo/7916...
# 3    4  https://www.shanghairanking.com/_uni/logo/8d98...
# 4    5  https://www.shanghairanking.com/_uni/logo/0ff1...
#
#                                           Name  \
# 0                           Harvard University
# 1                          Stanford University
# 2  Massachusetts Institute of Technology (MIT)
# 3                      University of Cambridge
# 4           University of California, Berkeley
#
#                                                 Link  \
# 0  https://www.shanghairanking.com/institution/ha...
# 1  https://www.shanghairanking.com/institution/st...
# 2  https://www.shanghairanking.com/institution/ma...
# 3  https://www.shanghairanking.com/institution/un...
# 4  https://www.shanghairanking.com/institution/un...
#
#                     Website  \
# 0    http://www.harvard.edu
# 1   http://www.stanford.edu
# 2       http://web.mit.edu/
# 3      http://www.cam.ac.uk
# 4      http://berkeley.edu/
#
#                                                 Flag          Country  \
# 0  https://www.shanghairanking.com/_pub/country-f...    United States
# 1  https://www.shanghairanking.com/_pub/country-f...    United States
# 2  https://www.shanghairanking.com/_pub/country-f...    United States
# 3  https://www.shanghairanking.com/_pub/country-f...   United Kingdom
# 4  https://www.shanghairanking.com/_pub/country-f...    United States
#
#           Region  Foundation_year  \
# 0  North America             1636
# 1  North America             1885
# 2  North America             1861
# 3         Europe             1318
# 4  North America             1868
#
#                                              Address  \
# 0   Harvard University, Cambridge, Massachusetts ...
# 1                                     450 Serra Mall
# 2                            77 Massachusetts Avenue
# 3                      The Old Schools, Trinity Lane
# 4   University of California, Berkeley, Berkeley,...
#
#                                                Intro  Total_Enrollment  \
# 0  Harvard University is devoted to excellence in...             41987
# 1  Stanford University is a research university t...             16163
# 2  The essence of MIT is our appetite for problem...             11084
# 3  The University of Cambridge’s mission is to co...             19875
# 4  Berkeley is internationally noted for its acad...             39874
#
#    Total_International_Enrollment  UG_Enrollment  International_UG_Enrollment  \
# 0                            24.0          14467                         10.1
# 1                            24.0           6994                         10.7
# 2                            16.8           4276                         14.5
# 3                            36.9          12265                         23.3
# 4                            17.7          29250                         19.0
#
#    PG_Enrollment  International_PG_Enrollment   latitude   longitude
# 0          27520                         20.1  42.367909  -71.126782
# 1           9169                         34.2  37.431314 -122.169365
# 2           6808                         18.2  42.358253  -71.096627
# 3           7610                         58.9  52.210946    0.092005
# 4          10624                         13.9  37.875500 -122.239069

# %%
shanghai_Rank2023
# Out:
#          Rank                                               Logo  \
# 0           1  https://www.shanghairanking.com/_uni/logo/032b...
# 1           2  https://www.shanghairanking.com/_uni/logo/13de...
# 2           3  https://www.shanghairanking.com/_uni/logo/7916...
# 3           4  https://www.shanghairanking.com/_uni/logo/8d98...
# 4           5  https://www.shanghairanking.com/_uni/logo/0ff1...
# ..        ...                                                ...
# 995  901-1000  https://www.shanghairanking.com/_uni/logo/1702...
# 996  901-1000  https://www.shanghairanking.com/_uni/logo/5762...
# 997  901-1000  https://www.shanghairanking.com/_uni/logo/5020...
# 998  901-1000  https://www.shanghairanking.com/_uni/logo/4f15...
# 999  901-1000  https://www.shanghairanking.com/_uni/logo/9316...
#
#                                             Name  \
# 0                             Harvard University
# 1                            Stanford University
# 2    Massachusetts Institute of Technology (MIT)
# 3                        University of Cambridge
# 4             University of California, Berkeley
# ..                                           ...
# 995                          Xinjiang University
# 996                       Xuzhou Medical College
# 997                           Yangtze University
# 998                           Yeshiva University
# 999     Zhongnan University of Economics and Law
#
#                                                   Link  \
# 0    https://www.shanghairanking.com/institution/ha...
# 1    https://www.shanghairanking.com/institution/st...
# 2    https://www.shanghairanking.com/institution/ma...
# 3    https://www.shanghairanking.com/institution/un...
# 4    https://www.shanghairanking.com/institution/un...
# ..                                                 ...
# 995  https://www.shanghairanking.com/institution/xi...
# 996  https://www.shanghairanking.com/institution/xu...
# 997  https://www.shanghairanking.com/institution/ya...
# 998  https://www.shanghairanking.com/institution/ye...
# 999  https://www.shanghairanking.com/institution/zh...
#
#                                                Website  \
# 0                               http://www.harvard.edu
# 1                              http://www.stanford.edu
# 2                                  http://web.mit.edu/
# 3                                 http://www.cam.ac.uk
# 4                                 http://berkeley.edu/
# ..                                                 ...
# 995  https://en.wikipedia.org/wiki/Xinjiang_University
# 996                       https://gjjyen.xzhmu.edu.cn/
# 997                   https://english.yangtzeu.edu.cn/
# 998                                  http://www.yu.edu
# 999                            http://www.znufe.edu.cn
#
#                                                   Flag          Country  \
# 0    https://www.shanghairanking.com/_pub/country-f...    United States
# 1    https://www.shanghairanking.com/_pub/country-f...    United States
# 2    https://www.shanghairanking.com/_pub/country-f...    United States
# 3    https://www.shanghairanking.com/_pub/country-f...   United Kingdom
# 4    https://www.shanghairanking.com/_pub/country-f...    United States
# ..                                                 ...              ...
# 995  https://www.shanghairanking.com/_pub/country-f...            China
# 996  https://www.shanghairanking.com/_pub/country-f...            China
# 997  https://www.shanghairanking.com/_pub/country-f...            China
# 998  https://www.shanghairanking.com/_pub/country-f...    United States
# 999  https://www.shanghairanking.com/_pub/country-f...            China
#
#             Region  Foundation_year  \
# 0    North America             1636
# 1    North America             1885
# 2    North America             1861
# 3           Europe             1318
# 4    North America             1868
# ..             ...              ...
# 995           Asia             1924
# 996           Asia             1958
# 997           Asia             2003
# 998  North America             1886
# 999           Asia             1948
#
#                                                Address  \
# 0     Harvard University, Cambridge, Massachusetts ...
# 1                                       450 Serra Mall
# 2                              77 Massachusetts Avenue
# 3                        The Old Schools, Trinity Lane
# 4     University of California, Berkeley, Berkeley,...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                500 West 185 Street
# 999   182# Nanhu Avenue, East Lake High-tech Develo...
#
#                                                  Intro  Total_Enrollment  \
# 0    Harvard University is devoted to excellence in...             41987
# 1    Stanford University is a research university t...             16163
# 2    The essence of MIT is our appetite for problem...             11084
# 3    The University of Cambridge’s mission is to co...             19875
# 4    Berkeley is internationally noted for its acad...             39874
# ..                                                 ...               ...
# 995                                                NaN             27010
# 996                                                NaN             27010
# 997                                                NaN             27010
# 998  Yeshiva University has been transforming lives...              7112
# 999  Zhongnan University of Economics and Law (ZUEL...             27010
#
#      Total_International_Enrollment  UG_Enrollment  \
# 0                              24.0          14467
# 1                              24.0           6994
# 2                              16.8           4276
# 3                              36.9          12265
# 4                              17.7          29250
# ..                              ...            ...
# 995                            13.3          19561
# 996                            13.3          19561
# 997                            13.3          19561
# 998                            13.3           2947
# 999                            13.3          19561
#
#      International_UG_Enrollment  PG_Enrollment  International_PG_Enrollment  \
# 0                           10.1          27520                         20.1
# 1                           10.7           9169                         34.2
# 2                           14.5           6808                         18.2
# 3                           23.3           7610                         58.9
# 4                           19.0          10624                         13.9
# ..                           ...            ...                          ...
# 995                         10.1           7793                         20.1
# 996                         10.1           7793                         20.1
# 997                         10.1           7793                         20.1
# 998                         10.1           4165                         20.1
# 999                         10.1           7793                         20.1
#
#       latitude   longitude
# 0    42.367909  -71.126782
# 1    37.431314 -122.169365
# 2    42.358253  -71.096627
# 3    52.210946    0.092005
# 4    37.875500 -122.239069
# ..         ...         ...
# 995  43.836840   87.575326
# 996  34.265655  117.169064
# 997  30.724085  111.311412
# 998  31.763492   35.191497
# 999  30.476433  114.380180
#
# [1000 rows x 19 columns]

# %%
shanghai_Rank2023["Country"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Times Higher Rank 2023 Impact Ranking

# %%
# Some ranks are duplicated because some universities obtained the same rank and the next rank is skipped accordingly

# %%
# remove "=" from duplicated rank

# %%
# Rankings are grouped into ranges, with every 100 ranks forming a separate range.

# %%
# sdg-score-multi__number stand for Impact Rankings for individual SDGs display just top 4 criteria
# sdg-score-multi__value show degree of criteria

# %%
# May delete ranking-institution-title href

# %%
Times_Higher_Rank.head()
# Out:
#   Rank           University Name   \
# 0    1  Western Sydney University
# 1    2   University of Manchester
# 2    3         Queen’s University
# 3    4  Universiti Sains Malaysia
# 4    5     University of Tasmania
#
#                       ranking-institution-title href        Location  \
# 0  https://www.timeshighereducation.com/world-uni...       Australia
# 1  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2  https://www.timeshighereducation.com/world-uni...          Canada
# 3  https://www.timeshighereducation.com/world-uni...        Malaysia
# 4  https://www.timeshighereducation.com/world-uni...       Australia
#
#    sdg-score-multi__number sdg-score-multi__value  sdg-score-multi__number 2  \
# 0                      5.0                   80.3                       12.0
# 1                     15.0                   97.4                       12.0
# 2                      2.0                   90.6                       16.0
# 3                     16.0                   94.1                        2.0
# 4                     13.0                   92.8                       15.0
#
#   sdg-score-multi__value 2  sdg-score-multi__number 3  \
# 0                     93.4                       15.0
# 1                     92.9                       11.0
# 2                     93.4                       11.0
# 3                     86.4                        1.0
# 4                     96.2                       14.0
#
#   sdg-score-multi__value 3 sdg-score-multi__value 4 scores  \
# 0                     96.7                     98.8   99.4
# 1                     92.2                     94.8   97.5
# 2                     91.0                     92.6   97.2
# 3                     84.9                     97.8   96.9
# 4                     95.1                     96.3   96.6
#
#    sdg-score-multi__number 5 sdg-score-multi__value 5  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 6 sdg-score-multi__value 6  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 7 sdg-score-multi__value 7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 8 sdg-score-multi__value 8
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN

# %%
Times_Higher_Rank["ranking-institution-title href"]
# Out:
# 0       https://www.timeshighereducation.com/world-uni...
# 1       https://www.timeshighereducation.com/world-uni...
# 2       https://www.timeshighereducation.com/world-uni...
# 3       https://www.timeshighereducation.com/world-uni...
# 4       https://www.timeshighereducation.com/world-uni...
#                               ...
# 1586    https://www.timeshighereducation.com/world-uni...
# 1587    https://www.timeshighereducation.com/world-uni...
# 1588    https://www.timeshighereducation.com/world-uni...
# 1589    https://www.timeshighereducation.com/world-uni...
# 1590    https://www.timeshighereducation.com/world-uni...
# Name: ranking-institution-title href, Length: 1591, dtype: object

# %%
Times_Higher_Rank[100: 200]
# Out:
#         Rank                   University Name   \
# 100     =100   Florida International University
# 101     =100             University of Plymouth
# 102  101–200            Abdullah Gül University
# 103  101–200                   Ahlia University
# 104  101–200              Universitas Airlangga
# ..       ...                                ...
# 195  101–200   Wageningen University & Research
# 196  101–200              University of Warwick
# 197  101–200  University of the West of England
# 198  101–200    University of the Witwatersrand
# 199  101–200            University of Worcester
#
#                         ranking-institution-title href        Location  \
# 100  https://www.timeshighereducation.com/world-uni...   United States
# 101  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 102  https://www.timeshighereducation.com/world-uni...          Turkey
# 103  https://www.timeshighereducation.com/world-uni...         Bahrain
# 104  https://www.timeshighereducation.com/world-uni...       Indonesia
# ..                                                 ...             ...
# 195  https://www.timeshighereducation.com/world-uni...     Netherlands
# 196  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 197  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 198  https://www.timeshighereducation.com/world-uni...    South Africa
# 199  https://www.timeshighereducation.com/world-uni...  United Kingdom
#
#      sdg-score-multi__number sdg-score-multi__value  \
# 100                     14.0                   95.9
# 101                      NaN                    NaN
# 102                      4.0                   73.1
# 103                     10.0                   86.4
# 104                      1.0                   82.7
# ..                       ...                    ...
# 195                     15.0                   84.3
# 196                     12.0                   90.7
# 197                      NaN                    NaN
# 198                      8.0                   80.3
# 199                     12.0                   78.1
#
#      sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 100                        NaN                      NaN
# 101                       11.0                     83.7
# 102                        1.0                     79.1
# 103                        NaN                      NaN
# 104                        5.0                     69.3
# ..                         ...                      ...
# 195                       14.0                     76.1
# 196                       16.0                     85.8
# 197                       12.0                     79.3
# 198                        3.0                73.5–78.9
# 199                        NaN                      NaN
#
#      sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 100                       15.0                     91.8
# 101                        2.0                     74.6
# 102                       11.0                67.1–76.0
# 103                        NaN                      NaN
# 104                        6.0                     75.5
# ..                         ...                      ...
# 195                        NaN                      NaN
# 196                       10.0                     77.3
# 197                       10.0                     79.3
# 198                       10.0                65.2–73.3
# 199                        NaN                      NaN
#
#     sdg-score-multi__value 4     scores  sdg-score-multi__number 5  \
# 100                     91.2       88.3                        6.0
# 101                81.9–86.9       88.3                        NaN
# 102                     89.0  82.2–88.2                        NaN
# 103                81.9–86.9  82.2–88.2                        8.0
# 104                75.6–81.7  82.2–88.2                        NaN
# ..                       ...        ...                        ...
# 195                75.6–81.7  82.2–88.2                        NaN
# 196                61.1–70.5  82.2–88.2                        NaN
# 197                70.6–75.5  82.2–88.2                        NaN
# 198                61.1–70.5  82.2–88.2                        NaN
# 199                75.6–81.7  82.2–88.2                       11.0
#
#     sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 100                     87.6                        NaN
# 101                      NaN                       12.0
# 102                      NaN                        NaN
# 103                     73.3                        NaN
# 104                      NaN                        NaN
# ..                       ...                        ...
# 195                      NaN                       12.0
# 196                      NaN                        NaN
# 197                      NaN                        5.0
# 198                      NaN                        NaN
# 199                     80.8                        5.0
#
#     sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 100                      NaN                        NaN
# 101                     83.8                        NaN
# 102                      NaN                        NaN
# 103                      NaN                        NaN
# 104                      NaN                        NaN
# ..                       ...                        ...
# 195                     86.2                        NaN
# 196                      NaN                        NaN
# 197                     70.3                        NaN
# 198                      NaN                        NaN
# 199                     73.4                        NaN
#
#     sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 100                      NaN                        NaN
# 101                      NaN                        NaN
# 102                      NaN                        NaN
# 103                      NaN                        NaN
# 104                      NaN                        NaN
# ..                       ...                        ...
# 195                      NaN                        NaN
# 196                      NaN                        NaN
# 197                      NaN                        NaN
# 198                      NaN                        NaN
# 199                      NaN                        NaN
#
#     sdg-score-multi__value 8
# 100                      NaN
# 101                      NaN
# 102                      NaN
# 103                      NaN
# 104                      NaN
# ..                       ...
# 195                      NaN
# 196                      NaN
# 197                      NaN
# 198                      NaN
# 199                      NaN
#
# [100 rows x 20 columns]

# %%
Times_Higher_Rank
# Out:
#        Rank                       University Name   \
# 0         1              Western Sydney University
# 1         2               University of Manchester
# 2         3                     Queen’s University
# 3         4              Universiti Sains Malaysia
# 4         5                 University of Tasmania
# ...     ...                                    ...
# 1586  1001+                       Zarqa University
# 1587  1001+  Zewail City of Science and Technology
# 1588  1001+  Zhytomyr Ivan Franko State University
# 1589  1001+                   University of Žilina
# 1590  1001+     Zonguldak Bülent Ecevit University
#
#                          ranking-institution-title href        Location  \
# 0     https://www.timeshighereducation.com/world-uni...       Australia
# 1     https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2     https://www.timeshighereducation.com/world-uni...          Canada
# 3     https://www.timeshighereducation.com/world-uni...        Malaysia
# 4     https://www.timeshighereducation.com/world-uni...       Australia
# ...                                                 ...             ...
# 1586  https://www.timeshighereducation.com/world-uni...          Jordan
# 1587  https://www.timeshighereducation.com/world-uni...           Egypt
# 1588  https://www.timeshighereducation.com/world-uni...         Ukraine
# 1589  https://www.timeshighereducation.com/world-uni...        Slovakia
# 1590  https://www.timeshighereducation.com/world-uni...          Turkey
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 0                         5.0                   80.3
# 1                        15.0                   97.4
# 2                         2.0                   90.6
# 3                        16.0                   94.1
# 4                        13.0                   92.8
# ...                       ...                    ...
# 1586                      NaN                    NaN
# 1587                      3.0              44.7–54.5
# 1588                      NaN                    NaN
# 1589                     11.0              20.9–38.4
# 1590                     12.0              49.4–58.6
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 0                          12.0                     93.4
# 1                          12.0                     92.9
# 2                          16.0                     93.4
# 3                           2.0                     86.4
# 4                          15.0                     96.2
# ...                         ...                      ...
# 1586                        NaN                      NaN
# 1587                        7.0                11.1–38.6
# 1588                       10.0                 3.9–25.5
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 0                          15.0                     96.7
# 1                          11.0                     92.2
# 2                          11.0                     91.0
# 3                           1.0                     84.9
# 4                          14.0                     95.1
# ...                         ...                      ...
# 1586                        1.0                23.3–38.1
# 1587                        NaN                      NaN
# 1588                        NaN                      NaN
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#      sdg-score-multi__value 4    scores  sdg-score-multi__number 5  \
# 0                        98.8      99.4                        NaN
# 1                        94.8      97.5                        NaN
# 2                        92.6      97.2                        NaN
# 3                        97.8      96.9                        NaN
# 4                        96.3      96.6                        NaN
# ...                       ...       ...                        ...
# 1586                 1.5–45.2  7.9–53.8                        NaN
# 1587                45.3–53.3  7.9–53.8                        1.0
# 1588                 1.5–45.2  7.9–53.8                        NaN
# 1589                 1.5–45.2  7.9–53.8                        NaN
# 1590                 1.5–45.2  7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                      NaN                        4.0
# 1587                54.5–60.1                        NaN
# 1588                      NaN                        8.0
# 1589                      NaN                        9.0
# 1590                      NaN                        7.0
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                43.6–50.9                        3.0
# 1587                      NaN                        NaN
# 1588                35.7–48.3                        5.0
# 1589                17.2–33.8                        NaN
# 1590                51.9–56.1                        3.0
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1586                32.1–44.6                        NaN
# 1587                      NaN                        NaN
# 1588                43.7–51.5                        NaN
# 1589                      NaN                        4.0
# 1590                54.7–63.8                        NaN
#
#      sdg-score-multi__value 8
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1586                      NaN
# 1587                      NaN
# 1588                      NaN
# 1589                 2.8–35.7
# 1590                      NaN
#
# [1591 rows x 20 columns]

# %% [markdown]
#  # World Rank University 2023 Academic Ranking

# %%
# We should modify the format pf 'University Names' and 'World Rank'

# %%
# Rankings are grouped into ranges out of 0.0%, with every 20 ranks forming a separate range.

# %%
World_Rank.head()
# Out:
#   World Rank                                   University Names  \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1  2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2  3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3  4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4  5Top 0.1%  University of Oxford\n  Education: A+; Employa...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# 2             USA              3               11                  4
# 3  United Kingdom              1                3                 25
# 4  United Kingdom              2                7                 27
#
#   Faculty Rank Research Rank  Score
# 0            1             1  100.0
# 1            3             9   96.7
# 2            2             2   95.2
# 3            5            11   94.1
# 4            9             4   93.3

# %%
World_Rank["World Rank"].duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Rank[1990:2000]
# Out:
#         World Rank                               University Names  \
# 1990  1991Top 9.7%                 Hunan University of Technology
# 1991  1992Top 9.8%   Zurich University of Applied Sciences (ZHAW)
# 1992  1993Top 9.8%                 Technical University of Košice
# 1993  1994Top 9.8%                     Guangdong Ocean University
# 1994  1995Top 9.8%  University of Djillali Liabès, Sidi Bel-Abbès
# 1995  1996Top 9.8%                  Chongqing Jiaotong University
# 1996  1997Top 9.8%          University of Arkansas at Little Rock
# 1997  1998Top 9.8%                     Van Yüzüncü Yıl University
# 1998  1999Top 9.8%                       Bharathidasan University
# 1999  2000Top 9.8%                     Gebze Technical University
#
#             Location   National Rank Educational Rank Employability Rank  \
# 1990            China            312                -                  -
# 1991      Switzerland             13                -                909
# 1992  Slovak Republic              4                -                  -
# 1993            China            313                -                  -
# 1994          Algeria              2                -                  -
# 1995            China            314                -                  -
# 1996              USA            332                -               1322
# 1997           Turkey             54                -                  -
# 1998            India             64                -                  -
# 1999           Turkey             55                -                  -
#
#      Faculty Rank Research Rank  Score
# 1990            -          1913   66.0
# 1991            -          1927   66.0
# 1992            -          1914   66.0
# 1993            -          1915   66.0
# 1994            -          1916   66.0
# 1995            -          1917   66.0
# 1996            -          1920   66.0
# 1997            -          1919   66.0
# 1998            -          1922   66.0
# 1999            -          1923   66.0

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
# Columns of each data set
print( "\n The columns in shanghai Ranking dataset are \n", shanghai_Rank2023.columns , "\n \n The columns in Times Higher Education dataset are \n " , Times_Higher_Rank.columns , "\n \n The columns in  World Rank University dataset are \n " , World_Rank.columns)

shanghai_Rank2023.info()

# %%
Times_Higher_Rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            1591 non-null   object
#  1   University Name                 1591 non-null   object
#  2   ranking-institution-title href  1500 non-null   object
#  3   Location                        1500 non-null   object
#  4   sdg-score-multi__number         867 non-null    float64
#  5   sdg-score-multi__value          867 non-null    object
#  6   sdg-score-multi__number 2       826 non-null    float64
#  7   sdg-score-multi__value 2        825 non-null    object
#  8   sdg-score-multi__number 3       812 non-null    float64
#  9   sdg-score-multi__value 3        805 non-null    object
#  10  sdg-score-multi__value 4        1583 non-null   object
#  11  scores                          1591 non-null   object
#  12  sdg-score-multi__number 5       565 non-null    float64
#  13  sdg-score-multi__value 5        557 non-null    object
#  14  sdg-score-multi__number 6       498 non-null    float64
#  15  sdg-score-multi__value 6        496 non-null    object
#  16  sdg-score-multi__number 7       439 non-null    float64
#  17  sdg-score-multi__value 7        439 non-null    object
#  18  sdg-score-multi__number 8       483 non-null    float64
#  19  sdg-score-multi__value 8        483 non-null    object
# dtypes: float64(7), object(13)
# memory usage: 248.7+ KB

# %%
World_Rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          2000 non-null   object
#  1   University Names    2000 non-null   object
#  2   Location            2000 non-null   object
#  3   National Rank       2000 non-null   int64
#  4   Educational Rank    2000 non-null   object
#  5   Employability Rank  2000 non-null   object
#  6   Faculty Rank        2000 non-null   object
#  7   Research Rank       2000 non-null   object
#  8   Score               2000 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 140.8+ KB

# %%
# There are duplicates in 'Rank' column
shanghai_Rank2023.describe(include='object')
# Out:
#             Rank                                               Logo  \
# count       1000                                               1000
# unique        91                                                979
# top     901-1000  https://www.shanghairanking.com/images/default...
# freq         100                                                 22
#
#                       Name                                               Link  \
# count                 1000                                               1000
# unique                1000                                               1000
# top     Harvard University  https://www.shanghairanking.com/institution/ha...
# freq                     1                                                  1
#
#                         Website  \
# count                      1000
# unique                     1000
# top      http://www.harvard.edu
# freq                          1
#
#                                                      Flag Country Region  \
# count                                                1000    1000   1000
# unique                                                 62      62      6
# top     https://www.shanghairanking.com/_pub/country-f...   China   Asia
# freq                                                  191     191    356
#
#                  Address                                              Intro
# count                862                                                592
# unique               843                                                592
# top      University Road  Harvard University is devoted to excellence in...
# freq                   3                                                  1

# %%
# Only 64 of 'Rank' column are unique so there are duplicates
# 1001+ has the most frequency
# Turkey has the most frequency in 'Location' column

# %%
Times_Higher_Rank.describe(include='object')
# Out:
#          Rank           University Name   \
# count    1591                       1591
# unique     64                       1591
# top     1001+  Western Sydney University
# freq      591                          1
#
#                            ranking-institution-title href Location  \
# count                                                1500     1500
# unique                                               1500      110
# top     https://www.timeshighereducation.com/world-uni...   Turkey
# freq                                                    1       79
#
#        sdg-score-multi__value sdg-score-multi__value 2  \
# count                     867                      825
# unique                    250                      236
# top                 73.0–87.2                45.2–58.6
# freq                       28                       22
#
#        sdg-score-multi__value 3 sdg-score-multi__value 4    scores  \
# count                       805                     1583      1591
# unique                      228                       87        64
# top                   48.4–57.7                 1.5–45.2  7.9–53.8
# freq                         20                      579       591
#
#        sdg-score-multi__value 5 sdg-score-multi__value 6  \
# count                       557                      496
# unique                      147                      143
# top                   44.7–54.5                48.4–57.7
# freq                         36                       23
#
#        sdg-score-multi__value 7 sdg-score-multi__value 8
# count                       439                      483
# unique                      113                      108
# top                   48.4–57.7                 2.8–35.7
# freq                         20                       33

# %%
# There are missing values in 'Educational Rank'	'Employability Rank'	'Faculty Rank'	'Research Rank'  columns that represented as '-'
World_Rank.describe(include='object')
# Out:
#        World Rank                                   University Names  \
# count        2000                                               2000
# unique       2000                                               2000
# top     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# freq            1                                                  1
#
#        Location  Educational Rank Employability Rank Faculty Rank  \
# count       2000             2000               2000         2000
# unique        95              439               1030          262
# top          USA                -                  -            -
# freq         332             1562                967         1727
#
#        Research Rank
# count           2000
# unique          1935
# top                -
# freq              66

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# The dataset was sourced from Kaggle (https://www.kaggle.com/datasets/ourfuture/world-university-rankings), and each ranking's credibility was verified.
# Shanghai Ranking (ARWU) uses objective indicators like Nobel laureates and highly cited researchers.
# CWUR focuses on faculty achievements, research output, and alumni success, avoiding reputation surveys. 
# Times HigherRank balances teaching, research, industry income, and international outlook, using verified university data and independent sources like Elsevier’s Scopus.
# Their transparent methodologies ensure reliability in assessing global universities.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# Using the 2023 Shanghai dataset ensures consistency across rankings (WR, THE, and Shanghai), avoiding bias from different years. 
# The stakeholders didn’t specify a need for the latest data, so we analyzed what was provided. 
# The weights of the criteria are calculated the same way in both 2022 and 2023, ensuring comparability.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# For consistency, all columns with the needed logical meaning are present in the datasets, but formatting adjustments were required to align them. 
# Ranking should be shown with the same format across all the three datasets
# This involved renaming columns, standardizing data types, and ensuring a uniform ranking structure across all datasets for accurate comparisons.

# %%
shanghai_Rank2023.head(1)
# Out:
#   Rank                                               Logo                Name  \
# 0    1  https://www.shanghairanking.com/_uni/logo/032b...  Harvard University
#
#                                                 Link                  Website  \
# 0  https://www.shanghairanking.com/institution/ha...   http://www.harvard.edu
#
#                                                 Flag         Country  \
# 0  https://www.shanghairanking.com/_pub/country-f...   United States
#
#           Region  Foundation_year  \
# 0  North America             1636
#
#                                              Address  \
# 0   Harvard University, Cambridge, Massachusetts ...
#
#                                                Intro  Total_Enrollment  \
# 0  Harvard University is devoted to excellence in...             41987
#
#    Total_International_Enrollment  UG_Enrollment  International_UG_Enrollment  \
# 0                            24.0          14467                         10.1
#
#    PG_Enrollment  International_PG_Enrollment   latitude  longitude
# 0          27520                         20.1  42.367909 -71.126782

# %%
Times_Higher_Rank.head(1)
# Out:
#   Rank           University Name   \
# 0    1  Western Sydney University
#
#                       ranking-institution-title href   Location  \
# 0  https://www.timeshighereducation.com/world-uni...  Australia
#
#    sdg-score-multi__number sdg-score-multi__value  sdg-score-multi__number 2  \
# 0                      5.0                   80.3                       12.0
#
#   sdg-score-multi__value 2  sdg-score-multi__number 3  \
# 0                     93.4                       15.0
#
#   sdg-score-multi__value 3 sdg-score-multi__value 4 scores  \
# 0                     96.7                     98.8   99.4
#
#    sdg-score-multi__number 5 sdg-score-multi__value 5  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 6 sdg-score-multi__value 6  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 7 sdg-score-multi__value 7  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 8 sdg-score-multi__value 8
# 0                        NaN                      NaN

# %%
World_Rank.head(1)
# Out:
#   World Rank                                   University Names Location   \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...       USA
#
#    National Rank Educational Rank Employability Rank Faculty Rank  \
# 0              1                1                  1            1
#
#   Research Rank  Score
# 0             1  100.0

# %%
shanghai_Rank2023.head(1)
# Out:
#   Rank                                               Logo     University Name  \
# 0    1  https://www.shanghairanking.com/_uni/logo/032b...  Harvard University
#
#                                                 Link                  Website  \
# 0  https://www.shanghairanking.com/institution/ha...   http://www.harvard.edu
#
#                                                 Flag         Country  \
# 0  https://www.shanghairanking.com/_pub/country-f...   United States
#
#           Region  Foundation_year  \
# 0  North America             1636
#
#                                              Address  \
# 0   Harvard University, Cambridge, Massachusetts ...
#
#                                                Intro  Total_Enrollment  \
# 0  Harvard University is devoted to excellence in...             41987
#
#    Total_International_Enrollment  UG_Enrollment  International_UG_Enrollment  \
# 0                            24.0          14467                         10.1
#
#    PG_Enrollment  International_PG_Enrollment   latitude  longitude
# 0          27520                         20.1  42.367909 -71.126782

# %%
# Ranking format should be modified, we checked the World Rank website and made sure that modifying it won't change the logical meaning
# Universities names are extracted with the wrong format we also checked the website and it should be cleaned in data cleaning
World_Rank.head(1)
# Out:
#   World Rank                                    University Name Location   \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...       USA
#
#    National Rank Educational Rank Employability Rank Faculty Rank  \
# 0              1                1                  1            1
#
#   Research Rank  Score
# 0             1  100.0

# %%
Times_Higher_Rank.head(1)
# Out:
#   Rank            University Name  \
# 0    1  Western Sydney University
#
#                       ranking-institution-title href   Location  \
# 0  https://www.timeshighereducation.com/world-uni...  Australia
#
#    sdg-score-multi__number sdg-score-multi__value  sdg-score-multi__number 2  \
# 0                      5.0                   80.3                       12.0
#
#   sdg-score-multi__value 2  sdg-score-multi__number 3  \
# 0                     93.4                       15.0
#
#   sdg-score-multi__value 3 sdg-score-multi__value 4 scores  \
# 0                     96.7                     98.8   99.4
#
#    sdg-score-multi__number 5 sdg-score-multi__value 5  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 6 sdg-score-multi__value 6  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 7 sdg-score-multi__value 7  \
# 0                        NaN                      NaN
#
#    sdg-score-multi__number 8 sdg-score-multi__value 8
# 0                        NaN                      NaN

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# For relevance, we ensured the dataset is representative of global university rankings, covering diverse institutions for a comprehensive analysis. 
# The sample aligns with our objectives, avoiding bias. Some columns are irrelevant and may be dropped in data cleaning, such as:

# Shanghai Rank 2022
# all columns seems relevant

# in Shanghai Rank 2023 dataset list of Columns that are irrelevant 
# ["Logo"]
# ["Link"]
# ["Website"]
# ["Foundation_year"]
# ["Address"]
# ["Intro"]
# ["latitude"]
# ["longitude"]

# in Times Higher Rank dataset one Column that is irrelevant
# ["Iranking-institution-title href"]

# World Rank University
# all columns seems relevant


# Using drop(axis=1, inplace=True), we will keep only meaningful data, preventing noise that could skew results.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
shanghai_Rank2022.head()
# Out:
#   Ranking                              University Name National/Regional Rank  \
# 0       1                           Harvard University                      1
# 1       2                          Stanford University                      2
# 2       3  Massachusetts Institute of Technology (MIT)                      3
# 3       4                      University of Cambridge                      1
# 4       5           University of California, Berkeley                      4
#
#    Total Score                                               LOGO  \
# 0        100.0  http://www.shanghairanking.com/_uni/logo/032bd...
# 1         76.8  http://www.shanghairanking.com/_uni/logo/13de8...
# 2         70.1  http://www.shanghairanking.com/_uni/logo/79165...
# 3         69.6  http://www.shanghairanking.com/_uni/logo/8d986...
# 4         65.3  http://www.shanghairanking.com/_uni/logo/0ff17...
#
#                                   University Detail
# 0  http://www.shanghairanking.com/institution/har...
# 1  http://www.shanghairanking.com/institution/sta...
# 2  http://www.shanghairanking.com/institution/mas...
# 3  http://www.shanghairanking.com/institution/uni...
# 4  http://www.shanghairanking.com/institution/uni...

# %%
shanghai_Rank2022.duplicated().sum()
# Out:
# 0

# %%
# Checking for the university name duplicates to make sure that the university isn't ranked more than once
shanghai_Rank2022["University Name"].duplicated().sum()
# Out:
# 0

# %%
shanghai_Rank2023.head()
# Out:
#   Rank                                               Logo  \
# 0    1  https://www.shanghairanking.com/_uni/logo/032b...
# 1    2  https://www.shanghairanking.com/_uni/logo/13de...
# 2    3  https://www.shanghairanking.com/_uni/logo/7916...
# 3    4  https://www.shanghairanking.com/_uni/logo/8d98...
# 4    5  https://www.shanghairanking.com/_uni/logo/0ff1...
#
#                                University Name  \
# 0                           Harvard University
# 1                          Stanford University
# 2  Massachusetts Institute of Technology (MIT)
# 3                      University of Cambridge
# 4           University of California, Berkeley
#
#                                                 Link  \
# 0  https://www.shanghairanking.com/institution/ha...
# 1  https://www.shanghairanking.com/institution/st...
# 2  https://www.shanghairanking.com/institution/ma...
# 3  https://www.shanghairanking.com/institution/un...
# 4  https://www.shanghairanking.com/institution/un...
#
#                     Website  \
# 0    http://www.harvard.edu
# 1   http://www.stanford.edu
# 2       http://web.mit.edu/
# 3      http://www.cam.ac.uk
# 4      http://berkeley.edu/
#
#                                                 Flag          Country  \
# 0  https://www.shanghairanking.com/_pub/country-f...    United States
# 1  https://www.shanghairanking.com/_pub/country-f...    United States
# 2  https://www.shanghairanking.com/_pub/country-f...    United States
# 3  https://www.shanghairanking.com/_pub/country-f...   United Kingdom
# 4  https://www.shanghairanking.com/_pub/country-f...    United States
#
#           Region  Foundation_year  \
# 0  North America             1636
# 1  North America             1885
# 2  North America             1861
# 3         Europe             1318
# 4  North America             1868
#
#                                              Address  \
# 0   Harvard University, Cambridge, Massachusetts ...
# 1                                     450 Serra Mall
# 2                            77 Massachusetts Avenue
# 3                      The Old Schools, Trinity Lane
# 4   University of California, Berkeley, Berkeley,...
#
#                                                Intro  Total_Enrollment  \
# 0  Harvard University is devoted to excellence in...             41987
# 1  Stanford University is a research university t...             16163
# 2  The essence of MIT is our appetite for problem...             11084
# 3  The University of Cambridge’s mission is to co...             19875
# 4  Berkeley is internationally noted for its acad...             39874
#
#    Total_International_Enrollment  UG_Enrollment  International_UG_Enrollment  \
# 0                            24.0          14467                         10.1
# 1                            24.0           6994                         10.7
# 2                            16.8           4276                         14.5
# 3                            36.9          12265                         23.3
# 4                            17.7          29250                         19.0
#
#    PG_Enrollment  International_PG_Enrollment   latitude   longitude
# 0          27520                         20.1  42.367909  -71.126782
# 1           9169                         34.2  37.431314 -122.169365
# 2           6808                         18.2  42.358253  -71.096627
# 3           7610                         58.9  52.210946    0.092005
# 4          10624                         13.9  37.875500 -122.239069

# %%
shanghai_Rank2023.duplicated().sum()
# Out:
# np.int64(0)

# %%
shanghai_Rank2023["University Name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
Times_Higher_Rank.head()
# Out:
#   Rank            University Name  \
# 0    1  Western Sydney University
# 1    2   University of Manchester
# 2    3         Queen’s University
# 3    4  Universiti Sains Malaysia
# 4    5     University of Tasmania
#
#                       ranking-institution-title href        Location  \
# 0  https://www.timeshighereducation.com/world-uni...       Australia
# 1  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2  https://www.timeshighereducation.com/world-uni...          Canada
# 3  https://www.timeshighereducation.com/world-uni...        Malaysia
# 4  https://www.timeshighereducation.com/world-uni...       Australia
#
#    sdg-score-multi__number sdg-score-multi__value  sdg-score-multi__number 2  \
# 0                      5.0                   80.3                       12.0
# 1                     15.0                   97.4                       12.0
# 2                      2.0                   90.6                       16.0
# 3                     16.0                   94.1                        2.0
# 4                     13.0                   92.8                       15.0
#
#   sdg-score-multi__value 2  sdg-score-multi__number 3  \
# 0                     93.4                       15.0
# 1                     92.9                       11.0
# 2                     93.4                       11.0
# 3                     86.4                        1.0
# 4                     96.2                       14.0
#
#   sdg-score-multi__value 3 sdg-score-multi__value 4 scores  \
# 0                     96.7                     98.8   99.4
# 1                     92.2                     94.8   97.5
# 2                     91.0                     92.6   97.2
# 3                     84.9                     97.8   96.9
# 4                     95.1                     96.3   96.6
#
#    sdg-score-multi__number 5 sdg-score-multi__value 5  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 6 sdg-score-multi__value 6  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 7 sdg-score-multi__value 7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 8 sdg-score-multi__value 8
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN

# %%
Times_Higher_Rank.duplicated().sum()
# Out:
# np.int64(0)

# %%
Times_Higher_Rank["University Name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Rank.head()
# Out:
#   World Rank                                    University Name  \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1  2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2  3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3  4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4  5Top 0.1%  University of Oxford\n  Education: A+; Employa...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# 2             USA              3               11                  4
# 3  United Kingdom              1                3                 25
# 4  United Kingdom              2                7                 27
#
#   Faculty Rank Research Rank  Score
# 0            1             1  100.0
# 1            3             9   96.7
# 2            2             2   95.2
# 3            5            11   94.1
# 4            9             4   93.3

# %%
World_Rank.duplicated().sum()
# Out:
# np.int64(0)

# %%
World_Rank["University Name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checked the uniqueness of all three datasets and ensured that columns with logical meaning preventing repetition do not contain any duplicates.

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %% [markdown]
# # Shanghai Rank 2022  Academic Ranking

# %%
shanghai_Rank2022.isnull().sum()
# Out:
# Ranking                   0
# University Name           0
# National/Regional Rank    0
# Total Score               0
# LOGO                      0
# University Detail         0
# dtype: int64

# %%
shanghai_Rank2022.describe(include='object')
# Out:
#          Ranking     University Name National/Regional Rank  \
# count       1000                1000                   1000
# unique        93                1000                    136
# top     901-1000  Harvard University                      1
# freq         100                   1                     59
#
#                                                      LOGO  \
# count                                                1000
# unique                                               1000
# top     http://www.shanghairanking.com/_uni/logo/032bd...
# freq                                                    1
#
#                                        University Detail
# count                                                1000
# unique                                               1000
# top     http://www.shanghairanking.com/institution/har...
# freq                                                    1

# %%
shanghai_Rank2022.tail(100)
# Out:
#       Ranking                                University Name  \
# 900  901-1000                     Adam Mickiewicz University
# 901  901-1000                      Aligarh Muslim University
# 902  901-1000                                Amherst College
# 903  901-1000                               Amity University
# 904  901-1000                             Bocconi University
# ..        ...                                            ...
# 995  901-1000                        University of Wuppertal
# 996  901-1000                Warsaw University of Technology
# 997  901-1000  Western Norway University of Applied Sciences
# 998  901-1000   Wroclaw University of Science and Technology
# 999  901-1000                              Yantai University
#
#     National/Regional Rank  Total Score  \
# 900                   7-11          0.0
# 901                   9-14          0.0
# 902                183-196         25.0
# 903                   9-14          0.0
# 904                  41-46          0.0
# ..                     ...          ...
# 995                  46-47          0.0
# 996                   7-11          0.0
# 997                    6-7          0.0
# 998                   7-11          0.0
# 999                148-163          0.0
#
#                                                   LOGO  \
# 900  http://www.shanghairanking.com/_uni/logo-jpg/8...
# 901  http://www.shanghairanking.com/_uni/logo/e0618...
# 902  http://www.shanghairanking.com/_uni/logo/dfcf2...
# 903  http://www.shanghairanking.com/_uni/logo/5237e...
# 904  http://www.shanghairanking.com/_uni/logo-jpg/9...
# ..                                                 ...
# 995  http://www.shanghairanking.com/_uni/logo/2ab2f...
# 996  http://www.shanghairanking.com/_uni/logo/a347c...
# 997  http://www.shanghairanking.com/_uni/logo-jpg/d...
# 998  http://www.shanghairanking.com/_uni/logo/ed480...
# 999  http://www.shanghairanking.com/_uni/logo/78347...
#
#                                     University Detail
# 900  http://www.shanghairanking.com/institution/ada...
# 901  http://www.shanghairanking.com/institution/ali...
# 902  http://www.shanghairanking.com/institution/amh...
# 903  http://www.shanghairanking.com/institution/ami...
# 904  http://www.shanghairanking.com/institution/boc...
# ..                                                 ...
# 995  http://www.shanghairanking.com/institution/uni...
# 996  http://www.shanghairanking.com/institution/war...
# 997  http://www.shanghairanking.com/institution/wes...
# 998  http://www.shanghairanking.com/institution/wro...
# 999  http://www.shanghairanking.com/institution/yan...
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Shanghai Rank 2023

# %%
# There are missing values in 'Address', 'Intro', 'latitude', 'longitude'
shanghai_Rank2023.isnull().sum()
# Out:
# Rank                                0
# Logo                                0
# University Name                     0
# Link                                0
# Website                             0
# Flag                                0
# Country                             0
# Region                              0
# Foundation_year                     0
# Address                           138
# Intro                             408
# Total_Enrollment                    0
# Total_International_Enrollment      0
# UG_Enrollment                       0
# International_UG_Enrollment         0
# PG_Enrollment                       0
# International_PG_Enrollment         0
# latitude                           83
# longitude                          83
# dtype: int64

# %%
shanghai_Rank2023.describe(include='object')
# Out:
#             Rank                                               Logo  \
# count       1000                                               1000
# unique        91                                                979
# top     901-1000  https://www.shanghairanking.com/images/default...
# freq         100                                                 22
#
#            University Name                                               Link  \
# count                 1000                                               1000
# unique                1000                                               1000
# top     Harvard University  https://www.shanghairanking.com/institution/ha...
# freq                     1                                                  1
#
#                         Website  \
# count                      1000
# unique                     1000
# top      http://www.harvard.edu
# freq                          1
#
#                                                      Flag Country Region  \
# count                                                1000    1000   1000
# unique                                                 62      62      6
# top     https://www.shanghairanking.com/_pub/country-f...   China   Asia
# freq                                                  191     191    356
#
#                  Address                                              Intro
# count                862                                                592
# unique               843                                                592
# top      University Road  Harvard University is devoted to excellence in...
# freq                   3                                                  1

# %%
# Understanding the ranking style in the dataset
shanghai_Rank2023["Rank"].value_counts()
# Out:
# Rank
# 901-1000    100
# 801-900     100
# 701-800     100
# 601-700     100
# 501-600     100
#            ...
# 28            1
# 27            1
# 26            1
# 25            1
# 51            1
# Name: count, Length: 91, dtype: int64

# %%
# This function checks all columns in a given DataFrame and returns the count of missing (NaN) values per column

# %%
def check_missing_values(df):

    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]  # Keep only columns with missing values
    return missing_values

# %%
check_missing_values(shanghai_Rank2023)
# Out:
# Address      138
# Intro        408
# latitude      83
# longitude     83
# dtype: int64

# %%
# These columns contain missing values and they are irrelevant to our use case. 
# Handling them would be time-consuming, so it’s more efficient to focus our efforts on relevant columns instead.

# %%
shanghai_Rank2023.drop(columns=[  "Address" , "Intro"  ,"latitude" ,"longitude"], inplace=True)

# %%
shanghai_Rank2023[100:300]
# Out:
#         Rank                                               Logo  \
# 100  101-150  https://www.shanghairanking.com/_uni/logo/4b70...
# 101  101-150  https://www.shanghairanking.com/_uni/logo/8538...
# 102  101-150  https://www.shanghairanking.com/_uni/logo/cbbf...
# 103  101-150  https://www.shanghairanking.com/_uni/logo/e1f8...
# 104  101-150  https://www.shanghairanking.com/_uni/logo/ed73...
# ..       ...                                                ...
# 295  201-300  https://www.shanghairanking.com/_uni/logo/9076...
# 296  201-300  https://www.shanghairanking.com/_uni/logo/0603...
# 297  201-300  https://www.shanghairanking.com/_uni/logo/e010...
# 298  201-300  https://www.shanghairanking.com/_uni/logo/1656...
# 299  201-300  https://www.shanghairanking.com/_uni/logo/9aca...
#
#                                        University Name  \
# 100                           Arizona State University
# 101                    Beijing Institute of Technology
# 102                                  Boston University
# 103                         Carnegie Mellon University
# 104                       City University of Hong Kong
# ..                                                 ...
# 295                            University of Wuerzburg
# 296                   Virginia Commonwealth University
# 297  Virginia Polytechnic Institute and State Unive...
# 298                     Wuhan University of Technology
# 299                                  Yonsei University
#
#                                                   Link  \
# 100  https://www.shanghairanking.com/institution/ar...
# 101  https://www.shanghairanking.com/institution/be...
# 102  https://www.shanghairanking.com/institution/bo...
# 103  https://www.shanghairanking.com/institution/ca...
# 104  https://www.shanghairanking.com/institution/ci...
# ..                                                 ...
# 295  https://www.shanghairanking.com/institution/un...
# 296  https://www.shanghairanking.com/institution/vi...
# 297  https://www.shanghairanking.com/institution/vi...
# 298  https://www.shanghairanking.com/institution/wu...
# 299  https://www.shanghairanking.com/institution/yo...
#
#                             Website  \
# 100              http://www.asu.edu
# 101           http://www.bit.edu.cn
# 102               http://www.bu.edu
# 103              http://www.cmu.edu
# 104         http://www.cityu.edu.hk
# ..                              ...
# 295    http://www.uni-wuerzburg.de/
# 296              http://www.vcu.edu
# 297               http://www.vt.edu
# 298         http://www.whut.edu.cn/
# 299   http://www.yonsei.ac.kr/en_sc
#
#                                                   Flag           Country  \
# 100  https://www.shanghairanking.com/_pub/country-f...     United States
# 101  https://www.shanghairanking.com/_pub/country-f...             China
# 102  https://www.shanghairanking.com/_pub/country-f...     United States
# 103  https://www.shanghairanking.com/_pub/country-f...     United States
# 104  https://www.shanghairanking.com/_pub/country-f...   China-Hong Kong
# ..                                                 ...               ...
# 295  https://www.shanghairanking.com/_pub/country-f...           Germany
# 296  https://www.shanghairanking.com/_pub/country-f...     United States
# 297  https://www.shanghairanking.com/_pub/country-f...     United States
# 298  https://www.shanghairanking.com/_pub/country-f...             China
# 299  https://www.shanghairanking.com/_pub/country-f...       South Korea
#
#             Region  Foundation_year  Total_Enrollment  \
# 100  North America             1885             48988
# 101           Asia             1940             28771
# 102  North America             1869             26147
# 103  North America             1900             14223
# 104           Asia             1984              9233
# ..             ...              ...               ...
# 295         Europe             1402             23383
# 296  North America             1837             33462
# 297  North America             1872             36322
# 298           Asia             1948             53884
# 299           Asia             1885             17744
#
#      Total_International_Enrollment  UG_Enrollment  \
# 100                            12.2          42070
# 101                             4.9          15429
# 102                            25.8          16080
# 103                            47.4           6868
# 104                            34.8           5845
# ..                              ...            ...
# 295                             5.7          10289
# 296                            13.3          25706
# 297                            13.8          29649
# 298                             2.5          37327
# 299                            22.0          19561
#
#      International_UG_Enrollment  PG_Enrollment  International_PG_Enrollment
# 100                         10.8           6918                         20.8
# 101                          4.5          13342                          5.4
# 102                         25.8          10067                         25.7
# 103                         26.9           7355                         66.6
# 104                         37.1           3388                         30.8
# ..                           ...            ...                          ...
# 295                          6.4          13094                          5.3
# 296                         10.1           7756                         20.1
# 297                          9.0           6673                         35.1
# 298                          1.6          16557                          4.6
# 299                         10.1           7793                         20.1
#
# [200 rows x 15 columns]

# %%
shanghai_Rank2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            1000 non-null   object
#  1   Logo                            1000 non-null   object
#  2   University Name                 1000 non-null   object
#  3   Link                            1000 non-null   object
#  4   Website                         1000 non-null   object
#  5   Flag                            1000 non-null   object
#  6   Country                         1000 non-null   object
#  7   Region                          1000 non-null   object
#  8   Foundation_year                 1000 non-null   int64
#  9   Total_Enrollment                1000 non-null   int64
#  10  Total_International_Enrollment  1000 non-null   float64
#  11  UG_Enrollment                   1000 non-null   int64
#  12  International_UG_Enrollment     1000 non-null   float64
#  13  PG_Enrollment                   1000 non-null   int64
#  14  International_PG_Enrollment     1000 non-null   float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 117.3+ KB

# %%
shanghai_Rank2023["Region"].value_counts()
# Out:
# Region
# Asia             356
# Europe           345
# North America    213
# Oceania           42
# Latin America     27
# Africa            17
# Name: count, dtype: int64

# %%
shanghai_Rank2023["Country"].value_counts()
# Out:
# Country
# China             191
# United States     187
# United Kingdom     64
# Germany            45
# Italy              40
#                  ...
# Ethiopia            1
# Qatar               1
# Croatia             1
# Argentina           1
# Tunisia             1
# Name: count, Length: 62, dtype: int64

# %%
shanghai_Rank2023.columns
# Out:
# Index(['Rank', 'Logo', 'University Name', 'Link', 'Website', 'Flag', 'Country',
#        'Region', 'Foundation_year', 'Total_Enrollment',
#        'Total_International_Enrollment', 'UG_Enrollment',
#        'International_UG_Enrollment', 'PG_Enrollment',
#        'International_PG_Enrollment'],
#       dtype='object')

# %%
shanghai_Rank2023[shanghai_Rank2023["Country"]  == "-"]
# Out:
# Empty DataFrame
# Columns: [Rank, Logo, University Name, Link, Website, Flag, Country, Region, Foundation_year, Total_Enrollment, Total_International_Enrollment, UG_Enrollment, International_UG_Enrollment, PG_Enrollment, International_PG_Enrollment]
# Index: []

# %% [markdown]
# # Times Higher Rank 2023

# %%
Times_Higher_Rank.isnull().sum()
# Out:
# Rank                                 0
# University Name                      0
# ranking-institution-title href      91
# Location                            91
# sdg-score-multi__number            724
# sdg-score-multi__value             724
# sdg-score-multi__number 2          765
# sdg-score-multi__value 2           766
# sdg-score-multi__number 3          779
# sdg-score-multi__value 3           786
# sdg-score-multi__value 4             8
# scores                               0
# sdg-score-multi__number 5         1026
# sdg-score-multi__value 5          1034
# sdg-score-multi__number 6         1093
# sdg-score-multi__value 6          1095
# sdg-score-multi__number 7         1152
# sdg-score-multi__value 7          1152
# sdg-score-multi__number 8         1108
# sdg-score-multi__value 8          1108
# dtype: int64

# %%
Times_Higher_Rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            1591 non-null   object
#  1   University Name                 1591 non-null   object
#  2   ranking-institution-title href  1500 non-null   object
#  3   Location                        1500 non-null   object
#  4   sdg-score-multi__number         867 non-null    float64
#  5   sdg-score-multi__value          867 non-null    object
#  6   sdg-score-multi__number 2       826 non-null    float64
#  7   sdg-score-multi__value 2        825 non-null    object
#  8   sdg-score-multi__number 3       812 non-null    float64
#  9   sdg-score-multi__value 3        805 non-null    object
#  10  sdg-score-multi__value 4        1583 non-null   object
#  11  scores                          1591 non-null   object
#  12  sdg-score-multi__number 5       565 non-null    float64
#  13  sdg-score-multi__value 5        557 non-null    object
#  14  sdg-score-multi__number 6       498 non-null    float64
#  15  sdg-score-multi__value 6        496 non-null    object
#  16  sdg-score-multi__number 7       439 non-null    float64
#  17  sdg-score-multi__value 7        439 non-null    object
#  18  sdg-score-multi__number 8       483 non-null    float64
#  19  sdg-score-multi__value 8        483 non-null    object
# dtypes: float64(7), object(13)
# memory usage: 248.7+ KB

# %%
Times_Higher_Rank[Times_Higher_Rank["scores"]  == "-"]
# Out:
# Empty DataFrame
# Columns: [Rank, University Name, ranking-institution-title href, Location, sdg-score-multi__number, sdg-score-multi__value, sdg-score-multi__number 2, sdg-score-multi__value 2, sdg-score-multi__number 3, sdg-score-multi__value 3, sdg-score-multi__value 4, scores, sdg-score-multi__number 5, sdg-score-multi__value 5, sdg-score-multi__number 6, sdg-score-multi__value 6, sdg-score-multi__number 7, sdg-score-multi__value 7, sdg-score-multi__number 8, sdg-score-multi__value 8]
# Index: []

# %%
Times_Higher_Rank.describe(include='object')
# Out:
#          Rank            University Name  \
# count    1591                       1591
# unique     64                       1591
# top     1001+  Western Sydney University
# freq      591                          1
#
#                            ranking-institution-title href Location  \
# count                                                1500     1500
# unique                                               1500      110
# top     https://www.timeshighereducation.com/world-uni...   Turkey
# freq                                                    1       79
#
#        sdg-score-multi__value sdg-score-multi__value 2  \
# count                     867                      825
# unique                    250                      236
# top                 73.0–87.2                45.2–58.6
# freq                       28                       22
#
#        sdg-score-multi__value 3 sdg-score-multi__value 4    scores  \
# count                       805                     1583      1591
# unique                      228                       87        64
# top                   48.4–57.7                 1.5–45.2  7.9–53.8
# freq                         20                      579       591
#
#        sdg-score-multi__value 5 sdg-score-multi__value 6  \
# count                       557                      496
# unique                      147                      143
# top                   44.7–54.5                48.4–57.7
# freq                         36                       23
#
#        sdg-score-multi__value 7 sdg-score-multi__value 8
# count                       439                      483
# unique                      113                      108
# top                   48.4–57.7                 2.8–35.7
# freq                         20                       33

# %%
Times_Higher_Rank.head()
# Out:
#   Rank            University Name  \
# 0    1  Western Sydney University
# 1    2   University of Manchester
# 2    3         Queen’s University
# 3    4  Universiti Sains Malaysia
# 4    5     University of Tasmania
#
#                       ranking-institution-title href        Location  \
# 0  https://www.timeshighereducation.com/world-uni...       Australia
# 1  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2  https://www.timeshighereducation.com/world-uni...          Canada
# 3  https://www.timeshighereducation.com/world-uni...        Malaysia
# 4  https://www.timeshighereducation.com/world-uni...       Australia
#
#    sdg-score-multi__number sdg-score-multi__value  sdg-score-multi__number 2  \
# 0                      5.0                   80.3                       12.0
# 1                     15.0                   97.4                       12.0
# 2                      2.0                   90.6                       16.0
# 3                     16.0                   94.1                        2.0
# 4                     13.0                   92.8                       15.0
#
#   sdg-score-multi__value 2  sdg-score-multi__number 3  \
# 0                     93.4                       15.0
# 1                     92.9                       11.0
# 2                     93.4                       11.0
# 3                     86.4                        1.0
# 4                     96.2                       14.0
#
#   sdg-score-multi__value 3 sdg-score-multi__value 4 scores  \
# 0                     96.7                     98.8   99.4
# 1                     92.2                     94.8   97.5
# 2                     91.0                     92.6   97.2
# 3                     84.9                     97.8   96.9
# 4                     95.1                     96.3   96.6
#
#    sdg-score-multi__number 5 sdg-score-multi__value 5  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 6 sdg-score-multi__value 6  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 7 sdg-score-multi__value 7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    sdg-score-multi__number 8 sdg-score-multi__value 8
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN

# %%
# The column ranking-institution-title href was removed because it contains links that are irrelevant to our analysis. 
# Since our use case focuses on ranking metrics rather than external references, keeping this column adds no analytical value. 
# Removing it helps streamline the dataset and improve processing efficiency.

# %%
Times_Higher_Rank["ranking-institution-title href"].isnull().sum()
# Out:
# np.int64(91)

# %%
Times_Higher_Rank.drop(columns=["ranking-institution-title href"], inplace=True)

# %%
Times_Higher_Rank.shape
# Out:
# (1591, 19)

# %%
check_missing_values(Times_Higher_Rank)
# Out:
# Location                       91
# sdg-score-multi__number       724
# sdg-score-multi__value        724
# sdg-score-multi__number 2     765
# sdg-score-multi__value 2      766
# sdg-score-multi__number 3     779
# sdg-score-multi__value 3      786
# sdg-score-multi__value 4        8
# sdg-score-multi__number 5    1026
# sdg-score-multi__value 5     1034
# sdg-score-multi__number 6    1093
# sdg-score-multi__value 6     1095
# sdg-score-multi__number 7    1152
# sdg-score-multi__value 7     1152
# sdg-score-multi__number 8    1108
# sdg-score-multi__value 8     1108
# dtype: int64

# %%
Times_Higher_Rank[Times_Higher_Rank['Location'].isnull()]#.describe(include='object')
# Out:
#          Rank                                    University Name Location  \
# 248   201–300                           Kazan Federal University      NaN
# 276   201–300  Peter the Great St Petersburg Polytechnic Univ...      NaN
# 285   201–300                                    RUDN University      NaN
# 303   301–400                             Altai State University      NaN
# 310   301–400           Bauman Moscow State Technical University      NaN
# ...       ...                                                ...      ...
# 1545    1001+                      Ural State Medical University      NaN
# 1560    1001+  V.I. Vernadsky Crimean Federal University (Ver...      NaN
# 1562    1001+               Volgograd State Technical University      NaN
# 1563    1001+                Voronezh State Technical University      NaN
# 1582    1001+            Yanka Kupala State University of Grodno      NaN
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 248                       8.0                   74.3
# 276                       9.0                   88.9
# 285                       4.0                   84.5
# 303                       4.0                   78.7
# 310                       4.0                   81.1
# ...                       ...                    ...
# 1545                      NaN                    NaN
# 1560                     16.0                    NaN
# 1562                      9.0              51.0–60.2
# 1563                      2.0              35.7–48.3
# 1582                     10.0              40.0–51.7
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 248                        16.0                     74.1
# 276                         8.0                66.4–71.5
# 285                         8.0                66.4–71.5
# 303                         8.0                66.4–71.5
# 310                        13.0                56.6–66.3
# ...                         ...                      ...
# 1545                        NaN                68.3–73.4
# 1560                        8.0                35.7–48.3
# 1562                       11.0                20.9–38.4
# 1563                        8.0                38.4–48.2
# 1582                       16.0                20.9–38.4
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 248                         4.0                75.6–81.7
# 276                        11.0                67.1–76.0
# 285                         5.0                     67.7
# 303                        16.0                53.4–61.0
# 310                         9.0                73.0–87.2
# ...                         ...                      ...
# 1545                        3.0                 1.5–45.2
# 1560                        9.0                33.9–50.8
# 1562                        8.0                57.8–62.2
# 1563                        1.0                 1.5–45.2
# 1582                       11.0                      NaN
#
#      sdg-score-multi__value 4     scores  sdg-score-multi__number 5  \
# 248                       NaN  76.8–82.1                        NaN
# 276                 75.6–81.7  76.8–82.1                        NaN
# 285                 53.4–61.0  76.8–82.1                        NaN
# 303                       NaN  72.7–76.7                        NaN
# 310                 61.1–70.5  72.7–76.7                        NaN
# ...                       ...        ...                        ...
# 1545                22.1–34.3   7.9–53.8                        5.0
# 1560                 1.5–45.2   7.9–53.8                        NaN
# 1562                 1.5–45.2   7.9–53.8                        NaN
# 1563                49.5–54.4   7.9–53.8                        NaN
# 1582                45.3–53.3   7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                25.6–39.9                       10.0
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                      NaN                        NaN
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                      NaN                        NaN
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 8
# 248                       NaN
# 276                       NaN
# 285                       NaN
# 303                       NaN
# 310                       NaN
# ...                       ...
# 1545                      NaN
# 1560                      NaN
# 1562                      NaN
# 1563                      NaN
# 1582                      NaN
#
# [91 rows x 19 columns]

# %%
Times_Higher_Rank['Location'] = Times_Higher_Rank['Location'].fillna('Other')

# %%
Times_Higher_Rank[Times_Higher_Rank['Location'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, University Name, Location, sdg-score-multi__number, sdg-score-multi__value, sdg-score-multi__number 2, sdg-score-multi__value 2, sdg-score-multi__number 3, sdg-score-multi__value 3, sdg-score-multi__value 4, scores, sdg-score-multi__number 5, sdg-score-multi__value 5, sdg-score-multi__number 6, sdg-score-multi__value 6, sdg-score-multi__number 7, sdg-score-multi__value 7, sdg-score-multi__number 8, sdg-score-multi__value 8]
# Index: []

# %%
check_missing_values(Times_Higher_Rank)
# Out:
# sdg-score-multi__number       724
# sdg-score-multi__value        724
# sdg-score-multi__number 2     765
# sdg-score-multi__value 2      766
# sdg-score-multi__number 3     779
# sdg-score-multi__value 3      786
# sdg-score-multi__value 4        8
# sdg-score-multi__number 5    1026
# sdg-score-multi__value 5     1034
# sdg-score-multi__number 6    1093
# sdg-score-multi__value 6     1095
# sdg-score-multi__number 7    1152
# sdg-score-multi__value 7     1152
# sdg-score-multi__number 8    1108
# sdg-score-multi__value 8     1108
# dtype: int64

# %%
Times_Higher_Rank.columns
# Out:
# Index(['Rank', 'University Name', 'Location', 'sdg-score-multi__number',
#        'sdg-score-multi__value', 'sdg-score-multi__number 2',
#        'sdg-score-multi__value 2', 'sdg-score-multi__number 3',
#        'sdg-score-multi__value 3', 'sdg-score-multi__value 4', 'scores',
#        'sdg-score-multi__number 5', 'sdg-score-multi__value 5',
#        'sdg-score-multi__number 6', 'sdg-score-multi__value 6',
#        'sdg-score-multi__number 7', 'sdg-score-multi__value 7',
#        'sdg-score-multi__number 8', 'sdg-score-multi__value 8'],
#       dtype='object')

# %%
columns_to_fill = [
       'sdg-score-multi__number',
       'sdg-score-multi__value', 'sdg-score-multi__number 2',
       'sdg-score-multi__value 2', 'sdg-score-multi__number 3',
       'sdg-score-multi__value 3', 'sdg-score-multi__value 4',
       'sdg-score-multi__number 5', 'sdg-score-multi__value 5',
       'sdg-score-multi__number 6', 'sdg-score-multi__value 6',
       'sdg-score-multi__number 7', 'sdg-score-multi__value 7',
       'sdg-score-multi__number 8', 'sdg-score-multi__value 8']

# %%
for column in columns_to_fill:
    if Times_Higher_Rank[column].dtype == 'float64':
        # Fill missing values for float columns
        Times_Higher_Rank[column] = Times_Higher_Rank[column].fillna(0.0)
    elif Times_Higher_Rank[column].dtype == 'object':
        # Fill missing values for object columns
        Times_Higher_Rank[column] = Times_Higher_Rank[column].fillna('0.0')

# %%
check_missing_values(Times_Higher_Rank)
# Out:
# Series([], dtype: int64)

# %%
Times_Higher_Rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1591 entries, 0 to 1590
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Rank                       1591 non-null   object
#  1   University Name            1591 non-null   object
#  2   Location                   1591 non-null   object
#  3   sdg-score-multi__number    1591 non-null   float64
#  4   sdg-score-multi__value     1591 non-null   object
#  5   sdg-score-multi__number 2  1591 non-null   float64
#  6   sdg-score-multi__value 2   1591 non-null   object
#  7   sdg-score-multi__number 3  1591 non-null   float64
#  8   sdg-score-multi__value 3   1591 non-null   object
#  9   sdg-score-multi__value 4   1591 non-null   object
#  10  scores                     1591 non-null   object
#  11  sdg-score-multi__number 5  1591 non-null   float64
#  12  sdg-score-multi__value 5   1591 non-null   object
#  13  sdg-score-multi__number 6  1591 non-null   float64
#  14  sdg-score-multi__value 6   1591 non-null   object
#  15  sdg-score-multi__number 7  1591 non-null   float64
#  16  sdg-score-multi__value 7   1591 non-null   object
#  17  sdg-score-multi__number 8  1591 non-null   float64
#  18  sdg-score-multi__value 8   1591 non-null   object
# dtypes: float64(7), object(12)
# memory usage: 236.3+ KB

# %%
Times_Higher_Rank.describe(include='object')
# Out:
#          Rank            University Name Location sdg-score-multi__value  \
# count    1591                       1591     1591                   1591
# unique     64                       1591      111                    251
# top     1001+  Western Sydney University    Other                    0.0
# freq      591                          1       91                    724
#
#        sdg-score-multi__value 2 sdg-score-multi__value 3  \
# count                      1591                     1591
# unique                      237                      229
# top                         0.0                      0.0
# freq                        766                      786
#
#        sdg-score-multi__value 4    scores sdg-score-multi__value 5  \
# count                      1591      1591                     1591
# unique                       88        64                      148
# top                    1.5–45.2  7.9–53.8                      0.0
# freq                        579       591                     1034
#
#        sdg-score-multi__value 6 sdg-score-multi__value 7  \
# count                      1591                     1591
# unique                      144                      114
# top                         0.0                      0.0
# freq                       1095                     1152
#
#        sdg-score-multi__value 8
# count                      1591
# unique                      109
# top                         0.0
# freq                       1108

# %%
Times_Higher_Rank["Rank"].value_counts()
# Out:
# Rank
# 1001+       591
# 601–800     205
# 401–600     199
# 801–1000    195
# 301–400     100
#            ...
# 39            1
# 2             1
# 56            1
# 57            1
# 55            1
# Name: count, Length: 64, dtype: int64

# %% [markdown]
#  # World Rank University 2023

# %%
World_Rank.isnull().sum()
# Out:
# World Rank            0
# University Name       0
# Location              0
# National Rank         0
# Educational Rank      0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
World_Rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   World Rank          2000 non-null   object
#  1   University Name     2000 non-null   object
#  2   Location            2000 non-null   object
#  3   National Rank       2000 non-null   int64
#  4   Educational Rank    2000 non-null   object
#  5   Employability Rank  2000 non-null   object
#  6   Faculty Rank        2000 non-null   object
#  7   Research Rank       2000 non-null   object
#  8   Score               2000 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 140.8+ KB

# %%
World_Rank.columns
# Out:
# Index(['World Rank', 'University Name', 'Location ', 'National Rank',
#        'Educational Rank', 'Employability Rank', 'Faculty Rank',
#        'Research Rank', 'Score'],
#       dtype='object')

# %%
check_missing_values(World_Rank)
# Out:
# Series([], dtype: int64)

# %%
World_Rank[World_Rank["Faculty Rank"] == "-"]
# Out:
#         World Rank                            University Name  Location   \
# 43      44Top 0.3%                        Tsinghua University      China
# 48      49Top 0.3%                          Peking University      China
# 54      55Top 0.3%  University of Chinese Academy of Sciences      China
# 73      74Top 0.4%              Shanghai Jiao Tong University      China
# 80      81Top 0.4%           National University of Singapore  Singapore
# ...            ...                                        ...        ...
# 1995  1996Top 9.8%              Chongqing Jiaotong University      China
# 1996  1997Top 9.8%      University of Arkansas at Little Rock        USA
# 1997  1998Top 9.8%                 Van Yüzüncü Yıl University     Turkey
# 1998  1999Top 9.8%                   Bharathidasan University      India
# 1999  2000Top 9.8%                 Gebze Technical University     Turkey
#
#       National Rank Educational Rank Employability Rank Faculty Rank  \
# 43                1              346                 56            -
# 48                2              369                 58            -
# 54                3                -               1304            -
# 73                4                -                140            -
# 80                1              365                181            -
# ...             ...              ...                ...          ...
# 1995            314                -                  -            -
# 1996            332                -               1322            -
# 1997             54                -                  -            -
# 1998             64                -                  -            -
# 1999             55                -                  -            -
#
#      Research Rank  Score
# 43              20   85.2
# 48              25   84.8
# 54               6   84.3
# 73              29   83.1
# 80              37   82.7
# ...            ...    ...
# 1995          1917   66.0
# 1996          1920   66.0
# 1997          1919   66.0
# 1998          1922   66.0
# 1999          1923   66.0
#
# [1727 rows x 9 columns]

# %%
World_Rank.describe(include='object')
# Out:
#        World Rank                                    University Name  \
# count        2000                                               2000
# unique       2000                                               2000
# top     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# freq            1                                                  1
#
#        Location  Educational Rank Employability Rank Faculty Rank  \
# count       2000             2000               2000         2000
# unique        95              439               1030          262
# top          USA                -                  -            -
# freq         332             1562                967         1727
#
#        Research Rank
# count           2000
# unique          1935
# top                -
# freq              66

# %%
World_Rank.head()
# Out:
#   World Rank                                    University Name  \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1  2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2  3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3  4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4  5Top 0.1%  University of Oxford\n  Education: A+; Employa...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# 2             USA              3               11                  4
# 3  United Kingdom              1                3                 25
# 4  United Kingdom              2                7                 27
#
#   Faculty Rank Research Rank  Score
# 0            1             1  100.0
# 1            3             9   96.7
# 2            2             2   95.2
# 3            5            11   94.1
# 4            9             4   93.3

# %%
World_Rank.shape
# Out:
# (2000, 9)

# %%
columns_to_update = [
    'Educational Rank', 'Employability Rank',
    'Faculty Rank', 'Research Rank'
]

# %%
# DATA CLEANING
for column in columns_to_update:
    World_Rank[column] = World_Rank[column].replace('-', '0')

# %%
World_Rank.describe(include='object')
# Out:
#        World Rank                                    University Name  \
# count        2000                                               2000
# unique       2000                                               2000
# top     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# freq            1                                                  1
#
#        Location  Educational Rank Employability Rank Faculty Rank  \
# count       2000             2000               2000         2000
# unique        95              439               1030          262
# top          USA         UnRanked           UnRanked     UnRanked
# freq         332             1562                967         1727
#
#        Research Rank
# count           2000
# unique          1935
# top         UnRanked
# freq              66

# %%
World_Rank[World_Rank["Faculty Rank"] == "-"]
# Out:
# Empty DataFrame
# Columns: [World Rank, University Name, Location , National Rank, Educational Rank, Employability Rank, Faculty Rank, Research Rank, Score]
# Index: []

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# 'Rank' column is an object since there are many ranging ranks in the dataset
# 'National/Regional Rank' can hold two values for either national or regional ranking but some have only one value 
# We can't change the type of the column 'National/Regional Rank' since we don't have enough details to determine how to split the column 
shanghai_Rank2022.dtypes
# Out:
# Ranking                    object
# University Name            object
# National/Regional Rank     object
# Total Score               float64
# LOGO                       object
# University Detail          object
# dtype: object

# %%
shanghai_Rank2022.tail()
# Out:
#       Ranking                                University Name  \
# 995  901-1000                        University of Wuppertal
# 996  901-1000                Warsaw University of Technology
# 997  901-1000  Western Norway University of Applied Sciences
# 998  901-1000   Wroclaw University of Science and Technology
# 999  901-1000                              Yantai University
#
#     National/Regional Rank  Total Score  \
# 995                  46-47          0.0
# 996                   7-11          0.0
# 997                    6-7          0.0
# 998                   7-11          0.0
# 999                148-163          0.0
#
#                                                   LOGO  \
# 995  http://www.shanghairanking.com/_uni/logo/2ab2f...
# 996  http://www.shanghairanking.com/_uni/logo/a347c...
# 997  http://www.shanghairanking.com/_uni/logo-jpg/d...
# 998  http://www.shanghairanking.com/_uni/logo/ed480...
# 999  http://www.shanghairanking.com/_uni/logo/78347...
#
#                                     University Detail
# 995  http://www.shanghairanking.com/institution/uni...
# 996  http://www.shanghairanking.com/institution/war...
# 997  http://www.shanghairanking.com/institution/wes...
# 998  http://www.shanghairanking.com/institution/wro...
# 999  http://www.shanghairanking.com/institution/yan...

# %% [markdown]
# ## Shanghai Rank 2023

# %%
shanghai_Rank2023.dtypes
# Out:
# Rank                               object
# Logo                               object
# Name                               object
# Link                               object
# Website                            object
# Flag                               object
# Country                            object
# Region                             object
# Foundation_year                     int64
# Address                            object
# Intro                              object
# Total_Enrollment                    int64
# Total_International_Enrollment    float64
# UG_Enrollment                       int64
# International_UG_Enrollment       float64
# PG_Enrollment                       int64
# International_PG_Enrollment       float64
# latitude                          float64
# longitude                         float64
# dtype: object

# %%
# IN DATA CLEANING
shanghai_Rank2023.Flag = shanghai_Rank2023.Flag.map(lambda x : x.split('100/')[1].split('.')[0])

# %% [markdown]
# ## Times Higher Rank

# %%
Times_Higher_Rank.dtypes
# Out:
# Rank                               object
# University Name                    object
# ranking-institution-title href     object
# Location                           object
# sdg-score-multi__number           float64
# sdg-score-multi__value             object
# sdg-score-multi__number 2         float64
# sdg-score-multi__value 2           object
# sdg-score-multi__number 3         float64
# sdg-score-multi__value 3           object
# sdg-score-multi__value 4           object
# scores                             object
# sdg-score-multi__number 5         float64
# sdg-score-multi__value 5           object
# sdg-score-multi__number 6         float64
# sdg-score-multi__value 6           object
# sdg-score-multi__number 7         float64
# sdg-score-multi__value 7           object
# sdg-score-multi__number 8         float64
# sdg-score-multi__value 8           object
# dtype: object

# %%
# 'Rank' column is object because some universities rank's is in a range 
# 'scores' column is object because some universities scored is in a range 
Times_Higher_Rank.tail()
# Out:
#        Rank                       University Name   \
# 1586  1001+                       Zarqa University
# 1587  1001+  Zewail City of Science and Technology
# 1588  1001+  Zhytomyr Ivan Franko State University
# 1589  1001+                   University of Žilina
# 1590  1001+     Zonguldak Bülent Ecevit University
#
#                          ranking-institution-title href  Location  \
# 1586  https://www.timeshighereducation.com/world-uni...    Jordan
# 1587  https://www.timeshighereducation.com/world-uni...     Egypt
# 1588  https://www.timeshighereducation.com/world-uni...   Ukraine
# 1589  https://www.timeshighereducation.com/world-uni...  Slovakia
# 1590  https://www.timeshighereducation.com/world-uni...    Turkey
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 1586                      NaN                    NaN
# 1587                      3.0              44.7–54.5
# 1588                      NaN                    NaN
# 1589                     11.0              20.9–38.4
# 1590                     12.0              49.4–58.6
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 1586                        NaN                      NaN
# 1587                        7.0                11.1–38.6
# 1588                       10.0                 3.9–25.5
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 1586                        1.0                23.3–38.1
# 1587                        NaN                      NaN
# 1588                        NaN                      NaN
# 1589                        NaN                      NaN
# 1590                        NaN                      NaN
#
#      sdg-score-multi__value 4    scores  sdg-score-multi__number 5  \
# 1586                 1.5–45.2  7.9–53.8                        NaN
# 1587                45.3–53.3  7.9–53.8                        1.0
# 1588                 1.5–45.2  7.9–53.8                        NaN
# 1589                 1.5–45.2  7.9–53.8                        NaN
# 1590                 1.5–45.2  7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 1586                      NaN                        4.0
# 1587                54.5–60.1                        NaN
# 1588                      NaN                        8.0
# 1589                      NaN                        9.0
# 1590                      NaN                        7.0
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 1586                43.6–50.9                        3.0
# 1587                      NaN                        NaN
# 1588                35.7–48.3                        5.0
# 1589                17.2–33.8                        NaN
# 1590                51.9–56.1                        3.0
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 1586                32.1–44.6                        NaN
# 1587                      NaN                        NaN
# 1588                43.7–51.5                        NaN
# 1589                      NaN                        4.0
# 1590                54.7–63.8                        NaN
#
#      sdg-score-multi__value 8
# 1586                      NaN
# 1587                      NaN
# 1588                      NaN
# 1589                 2.8–35.7
# 1590                      NaN

# %% [markdown]
# ## World Rank

# %%
World_Rank.dtypes
# Out:
# World Rank             object
# University Names       object
# Location               object
# National Rank           int64
# Educational Rank       object
# Employability Rank     object
# Faculty Rank           object
# Research Rank          object
# Score                 float64
# dtype: object

# %%
World_Rank.head()
# Out:
#   World Rank                                   University Names  \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1  2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2  3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3  4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4  5Top 0.1%  University of Oxford\n  Education: A+; Employa...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# 2             USA              3               11                  4
# 3  United Kingdom              1                3                 25
# 4  United Kingdom              2                7                 27
#
#   Faculty Rank Research Rank  Score
# 0            1             1  100.0
# 1            3             9   96.7
# 2            2             2   95.2
# 3            5            11   94.1
# 4            9             4   93.3

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.

# %% [markdown]
# ## Shanghai Rank 2022

# %%
shanghai_Rank2022.head()
# Out:
#   Ranking                              University Name National/Regional Rank  \
# 0       1                           Harvard University                      1
# 1       2                          Stanford University                      2
# 2       3  Massachusetts Institute of Technology (MIT)                      3
# 3       4                      University of Cambridge                      1
# 4       5           University of California, Berkeley                      4
#
#    Total Score                                               LOGO  \
# 0        100.0  http://www.shanghairanking.com/_uni/logo/032bd...
# 1         76.8  http://www.shanghairanking.com/_uni/logo/13de8...
# 2         70.1  http://www.shanghairanking.com/_uni/logo/79165...
# 3         69.6  http://www.shanghairanking.com/_uni/logo/8d986...
# 4         65.3  http://www.shanghairanking.com/_uni/logo/0ff17...
#
#                                   University Detail
# 0  http://www.shanghairanking.com/institution/har...
# 1  http://www.shanghairanking.com/institution/sta...
# 2  http://www.shanghairanking.com/institution/mas...
# 3  http://www.shanghairanking.com/institution/uni...
# 4  http://www.shanghairanking.com/institution/uni...

# %%
# Checking if there is any '-' in 'Total Score' column
shanghai_Rank2022[shanghai_Rank2022["Total Score"]  == "-"]
# Out:
# Empty DataFrame
# Columns: [Ranking, University Name, National/Regional Rank, Total Score, LOGO, University Detail ]
# Index: []

# %%
check_missing_values(shanghai_Rank2022)
# Out:
# Series([], dtype: int64)

# %%
shanghai_Rank2022["Ranking"].value_counts()
# Out:
# Ranking
# 901-1000    100
# 501-600     100
# 301-400     100
# 401-500     100
# 201-300     100
#            ...
# 29            1
# 28            1
# 27            1
# 26            1
# 50            1
# Name: count, Length: 93, dtype: int64

# %%
# No null values in the Scores
shanghai_Rank2022["Total Score"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Shanghai Rank 2023

# %%
check_missing_values(shanghai_Rank2023)
# Out:
# Address      138
# Intro        408
# latitude      83
# longitude     83
# dtype: int64

# %%
shanghai_Rank2023.drop(columns=[  "Address" , "Intro"  ,"latitude" ,"longitude"], inplace=True)

# %%
def check_missing_values(df):

    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]  # Keep only columns with missing values
    return missing_values

# %%
shanghai_Rank2023 = shanghai_Rank2023.rename(columns={'Name': 'University Name' })

# %% [markdown]
# # Times Higher Education 2023

# %%
Times_Higher_Rank["ranking-institution-title href"].isnull().sum()
# Out:
# np.int64(91)

# %%
Times_Higher_Rank.drop(columns=["ranking-institution-title href"], inplace=True)

# %%
Times_Higher_Rank.shape
# Out:
# (1591, 19)

# %%
check_missing_values(Times_Higher_Rank)
# Out:
# Location                       91
# sdg-score-multi__number       724
# sdg-score-multi__value        724
# sdg-score-multi__number 2     765
# sdg-score-multi__value 2      766
# sdg-score-multi__number 3     779
# sdg-score-multi__value 3      786
# sdg-score-multi__value 4        8
# sdg-score-multi__number 5    1026
# sdg-score-multi__value 5     1034
# sdg-score-multi__number 6    1093
# sdg-score-multi__value 6     1095
# sdg-score-multi__number 7    1152
# sdg-score-multi__value 7     1152
# sdg-score-multi__number 8    1108
# sdg-score-multi__value 8     1108
# dtype: int64

# %%
Times_Higher_Rank[Times_Higher_Rank['Location'].isnull()]#.describe(include='object')
# Out:
#          Rank                                    University Name Location  \
# 248   201–300                           Kazan Federal University      NaN
# 276   201–300  Peter the Great St Petersburg Polytechnic Univ...      NaN
# 285   201–300                                    RUDN University      NaN
# 303   301–400                             Altai State University      NaN
# 310   301–400           Bauman Moscow State Technical University      NaN
# ...       ...                                                ...      ...
# 1545    1001+                      Ural State Medical University      NaN
# 1560    1001+  V.I. Vernadsky Crimean Federal University (Ver...      NaN
# 1562    1001+               Volgograd State Technical University      NaN
# 1563    1001+                Voronezh State Technical University      NaN
# 1582    1001+            Yanka Kupala State University of Grodno      NaN
#
#       sdg-score-multi__number sdg-score-multi__value  \
# 248                       8.0                   74.3
# 276                       9.0                   88.9
# 285                       4.0                   84.5
# 303                       4.0                   78.7
# 310                       4.0                   81.1
# ...                       ...                    ...
# 1545                      NaN                    NaN
# 1560                     16.0                    NaN
# 1562                      9.0              51.0–60.2
# 1563                      2.0              35.7–48.3
# 1582                     10.0              40.0–51.7
#
#       sdg-score-multi__number 2 sdg-score-multi__value 2  \
# 248                        16.0                     74.1
# 276                         8.0                66.4–71.5
# 285                         8.0                66.4–71.5
# 303                         8.0                66.4–71.5
# 310                        13.0                56.6–66.3
# ...                         ...                      ...
# 1545                        NaN                68.3–73.4
# 1560                        8.0                35.7–48.3
# 1562                       11.0                20.9–38.4
# 1563                        8.0                38.4–48.2
# 1582                       16.0                20.9–38.4
#
#       sdg-score-multi__number 3 sdg-score-multi__value 3  \
# 248                         4.0                75.6–81.7
# 276                        11.0                67.1–76.0
# 285                         5.0                     67.7
# 303                        16.0                53.4–61.0
# 310                         9.0                73.0–87.2
# ...                         ...                      ...
# 1545                        3.0                 1.5–45.2
# 1560                        9.0                33.9–50.8
# 1562                        8.0                57.8–62.2
# 1563                        1.0                 1.5–45.2
# 1582                       11.0                      NaN
#
#      sdg-score-multi__value 4     scores  sdg-score-multi__number 5  \
# 248                       NaN  76.8–82.1                        NaN
# 276                 75.6–81.7  76.8–82.1                        NaN
# 285                 53.4–61.0  76.8–82.1                        NaN
# 303                       NaN  72.7–76.7                        NaN
# 310                 61.1–70.5  72.7–76.7                        NaN
# ...                       ...        ...                        ...
# 1545                22.1–34.3   7.9–53.8                        5.0
# 1560                 1.5–45.2   7.9–53.8                        NaN
# 1562                 1.5–45.2   7.9–53.8                        NaN
# 1563                49.5–54.4   7.9–53.8                        NaN
# 1582                45.3–53.3   7.9–53.8                        NaN
#
#      sdg-score-multi__value 5  sdg-score-multi__number 6  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                25.6–39.9                       10.0
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 6  sdg-score-multi__number 7  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                      NaN                        NaN
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 7  sdg-score-multi__number 8  \
# 248                       NaN                        NaN
# 276                       NaN                        NaN
# 285                       NaN                        NaN
# 303                       NaN                        NaN
# 310                       NaN                        NaN
# ...                       ...                        ...
# 1545                      NaN                        NaN
# 1560                      NaN                        NaN
# 1562                      NaN                        NaN
# 1563                      NaN                        NaN
# 1582                      NaN                        NaN
#
#      sdg-score-multi__value 8
# 248                       NaN
# 276                       NaN
# 285                       NaN
# 303                       NaN
# 310                       NaN
# ...                       ...
# 1545                      NaN
# 1560                      NaN
# 1562                      NaN
# 1563                      NaN
# 1582                      NaN
#
# [91 rows x 19 columns]

# %%
Times_Higher_Rank['Location'] = Times_Higher_Rank['Location'].fillna('Other')

# %%
Times_Higher_Rank[Times_Higher_Rank['Location'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, University Name, Location, sdg-score-multi__number, sdg-score-multi__value, sdg-score-multi__number 2, sdg-score-multi__value 2, sdg-score-multi__number 3, sdg-score-multi__value 3, sdg-score-multi__value 4, scores, sdg-score-multi__number 5, sdg-score-multi__value 5, sdg-score-multi__number 6, sdg-score-multi__value 6, sdg-score-multi__number 7, sdg-score-multi__value 7, sdg-score-multi__number 8, sdg-score-multi__value 8]
# Index: []

# %%
check_missing_values(Times_Higher_Rank)
# Out:
# sdg-score-multi__number       724
# sdg-score-multi__value        724
# sdg-score-multi__number 2     765
# sdg-score-multi__value 2      766
# sdg-score-multi__number 3     779
# sdg-score-multi__value 3      786
# sdg-score-multi__value 4        8
# sdg-score-multi__number 5    1026
# sdg-score-multi__value 5     1034
# sdg-score-multi__number 6    1093
# sdg-score-multi__value 6     1095
# sdg-score-multi__number 7    1152
# sdg-score-multi__value 7     1152
# sdg-score-multi__number 8    1108
# sdg-score-multi__value 8     1108
# dtype: int64

# %%
Times_Higher_Rank.columns
# Out:
# Index(['Rank', 'University Name', 'Location', 'sdg-score-multi__number',
#        'sdg-score-multi__value', 'sdg-score-multi__number 2',
#        'sdg-score-multi__value 2', 'sdg-score-multi__number 3',
#        'sdg-score-multi__value 3', 'sdg-score-multi__value 4', 'scores',
#        'sdg-score-multi__number 5', 'sdg-score-multi__value 5',
#        'sdg-score-multi__number 6', 'sdg-score-multi__value 6',
#        'sdg-score-multi__number 7', 'sdg-score-multi__value 7',
#        'sdg-score-multi__number 8', 'sdg-score-multi__value 8'],
#       dtype='object')

# %%
columns_to_fill = [
       'sdg-score-multi__number',
       'sdg-score-multi__value', 'sdg-score-multi__number 2',
       'sdg-score-multi__value 2', 'sdg-score-multi__number 3',
       'sdg-score-multi__value 3', 'sdg-score-multi__value 4',
       'sdg-score-multi__number 5', 'sdg-score-multi__value 5',
       'sdg-score-multi__number 6', 'sdg-score-multi__value 6',
       'sdg-score-multi__number 7', 'sdg-score-multi__value 7',
       'sdg-score-multi__number 8', 'sdg-score-multi__value 8']

# %%
for column in columns_to_fill:
    if Times_Higher_Rank[column].dtype == 'float64':
        # Fill missing values for float columns
        Times_Higher_Rank[column] = Times_Higher_Rank[column].fillna(0.0)
    elif Times_Higher_Rank[column].dtype == 'object':
        # Fill missing values for object columns
        Times_Higher_Rank[column] = Times_Higher_Rank[column].fillna('0.0')

# %%
Times_Higher_Rank = Times_Higher_Rank.rename(columns={'University Name ': 'University Name'})

# %% [markdown]
# # World Rank

# %%
def clean_university_name(name):

    # Split the name using regex for '\n', '\', ',', or any dash
    name = re.split(r'[\n\\,–—-]', name)[0].strip()
    return name

# Apply the function to the DataFrame
World_Rank['University Name'] = World_Rank['University Name'].astype(str).apply(clean_university_name)
# Display the cleaned names
World_Rank.head()

# %%
World_Rank[World_Rank["Faculty Rank"] == "-"]
# Out:
#         World Rank                            University Name  Location   \
# 43      44Top 0.3%                        Tsinghua University      China
# 48      49Top 0.3%                          Peking University      China
# 54      55Top 0.3%  University of Chinese Academy of Sciences      China
# 73      74Top 0.4%              Shanghai Jiao Tong University      China
# 80      81Top 0.4%           National University of Singapore  Singapore
# ...            ...                                        ...        ...
# 1995  1996Top 9.8%              Chongqing Jiaotong University      China
# 1996  1997Top 9.8%      University of Arkansas at Little Rock        USA
# 1997  1998Top 9.8%                 Van Yüzüncü Yıl University     Turkey
# 1998  1999Top 9.8%                   Bharathidasan University      India
# 1999  2000Top 9.8%                 Gebze Technical University     Turkey
#
#       National Rank Educational Rank Employability Rank Faculty Rank  \
# 43                1              346                 56            -
# 48                2              369                 58            -
# 54                3                -               1304            -
# 73                4                -                140            -
# 80                1              365                181            -
# ...             ...              ...                ...          ...
# 1995            314                -                  -            -
# 1996            332                -               1322            -
# 1997             54                -                  -            -
# 1998             64                -                  -            -
# 1999             55                -                  -            -
#
#      Research Rank  Score
# 43              20   85.2
# 48              25   84.8
# 54               6   84.3
# 73              29   83.1
# 80              37   82.7
# ...            ...    ...
# 1995          1917   66.0
# 1996          1920   66.0
# 1997          1919   66.0
# 1998          1922   66.0
# 1999          1923   66.0
#
# [1727 rows x 9 columns]

# %%
World_Rank.describe(include='object')
# Out:
#        World Rank                                    University Name  \
# count        2000                                               2000
# unique       2000                                               2000
# top     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# freq            1                                                  1
#
#        Location  Educational Rank Employability Rank Faculty Rank  \
# count       2000             2000               2000         2000
# unique        95              439               1030          262
# top          USA                -                  -            -
# freq         332             1562                967         1727
#
#        Research Rank
# count           2000
# unique          1935
# top                -
# freq              66

# %%
World_Rank.head()
# Out:
#   World Rank                                    University Name  \
# 0  1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1  2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2  3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3  4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4  5Top 0.1%  University of Oxford\n  Education: A+; Employa...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# 2             USA              3               11                  4
# 3  United Kingdom              1                3                 25
# 4  United Kingdom              2                7                 27
#
#   Faculty Rank Research Rank  Score
# 0            1             1  100.0
# 1            3             9   96.7
# 2            2             2   95.2
# 3            5            11   94.1
# 4            9             4   93.3

# %%
World_Rank.shape
# Out:
# (2000, 9)

# %%
columns_to_update = [
    'Educational Rank', 'Employability Rank',
    'Faculty Rank', 'Research Rank'
]

# %%
# DATA CLEANING
for column in columns_to_update:
    World_Rank[column] = World_Rank[column].replace('-', '0')

# %%
World_Rank.describe(include='object')
# Out:
#        World Rank                                    University Name  \
# count        2000                                               2000
# unique       2000                                               2000
# top     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# freq            1                                                  1
#
#        Location  Educational Rank Employability Rank Faculty Rank  \
# count       2000             2000               2000         2000
# unique        95              439               1030          262
# top          USA         UnRanked           UnRanked     UnRanked
# freq         332             1562                967         1727
#
#        Research Rank
# count           2000
# unique          1935
# top         UnRanked
# freq              66

# %%
World_Rank[World_Rank["Faculty Rank"] == "-"]
# Out:
# Empty DataFrame
# Columns: [World Rank, University Name, Location , National Rank, Educational Rank, Employability Rank, Faculty Rank, Research Rank, Score]
# Index: []

# %%
World_Rank = World_Rank.rename(columns={'ULocation ': 'Location'})

# %%
def extract_rank(rank_value):
   
    match = re.search(r'^\d+', str(rank_value))  # Find the leading number
    return str(match.group()) if match else None  # Convert to string if found

# Apply the function to the 'Rank' column
World_Rank['World Rank'] = World_Rank['World Rank'].apply(extract_rank)


World_Rank.head()

# %%
def process_rank(rank):
    if isinstance(rank, str) and '=' in rank:
        return int(rank.replace('=', '').strip())
    elif isinstance(rank, str) and rank.isdigit():
        return int(rank)
    else:
        return rank

def clean_tied_ranks(df, rank_column):
    df[rank_column] = df[rank_column].apply(process_rank)

clean_tied_ranks(Times_Higher_Rank, 'Rank')
Times_Higher_Rank.head()
